# %%
import hail as hl
import pandas as pd
# Parameters
log_path = '../logs/hail'
file_in = '../data/merged.vcf.gz'
file_out = '../data/merged.mt'

# %%
hl.init(app_name = 'gnomAD', log = log_path)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c7a6142c-7431-49e7-ae25-314fa19a42a5">Loading BokehJS ...</span>
#     </div>
# 25/10/31 22:21:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Running on Apache Spark version 3.5.7
# SparkUI available at http://pimenta:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.136-c32f88309ab0
# LOGGING: writing to ../logs/hail/
# 2025-10-31 22:21:30.525 Hail: INFO: scanning VCF for sortedness...
# 2025-10-31 22:21:32.466 Hail: INFO: Coerced sorted VCF - no additional import work to do
# 2025-10-31 22:21:34.076 Hail: INFO: wrote matrix table with 2000 rows and 0 columns in 1 partition to ../data/merged.mt
# 2025-10-31 22:31:02.810 Hail: INFO: wrote matrix table with 2000 rows and 0 columns in 1 partition to ../data/merged.mt
# 2025-10-31 22:44:40.151 Hail: INFO: merging 2 files totalling 458,3K...
# 2025-10-31 22:44:40.160 Hail: INFO: while writing:
#     ../data/variant_stats.tsv
#   merge time: 7,899ms

# %%
# Import and write matrix table
mt = hl.import_vcf(file_in, force_bgz=True, reference_genome='GRCh38')
mt.write(file_out, overwrite=True)

# %%
mt = hl.read_matrix_table(file_out)

# %%
# Here need to be changed in the real dataset. The current dataset is just a mockup.
# For example, adding annotations from gnomAD, filtering samples, etc.
# # Calculate basic allele statistics (similar to gnomAD)
# mt = hl.variant_qc(mt)
print("Matrix table schema:")
mt.describe()
# Out:
# Matrix table schema:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         AC: array<int32>,
#         AN: int32,
#         AF: array<float64>,
#         grpmax: array<str>,
#         fafmax_faf95_max: array<float64>,
#         fafmax_faf95_max_gen_anc: array<str>,
#         AC_XX: array<int32>,
#         AF_XX: array<float64>,
#         AN_XX: int32,
#         nhomalt_XX: array<int32>,
#         AC_XY: array<int32>,
#         AF_XY: array<float64>,
#         AN_XY: int32,
#         nhomalt_XY: array<int32>,
#         nhomalt: array<int32>,
#         AC_afr_XX: array<int32>,
#         AF_afr_XX: array<float64>,
#         AN_afr_XX: int32,
#         nhomalt_afr_XX: array<int32>,
#         AC_afr_XY: array<int32>,
#         AF_afr_XY: array<float64>,
#         AN_afr_XY: int32,
#         nhomalt_afr_XY: array<int32>,
#         AC_afr: array<int32>,
#         AF_afr: array<float64>,
#         AN_afr: int32,
#         nhomalt_afr: array<int32>,
#         AC_amr_XX: array<int32>,
#         AF_amr_XX: array<float64>,
#         AN_amr_XX: int32,
#         nhomalt_amr_XX: array<int32>,
#         AC_amr_XY: array<int32>,
#         AF_amr_XY: array<float64>,
#         AN_amr_XY: int32,
#         nhomalt_amr_XY: array<int32>,
#         AC_amr: array<int32>,
#         AF_amr: array<float64>,
#         AN_amr: int32,
#         nhomalt_amr: array<int32>,
#         AC_asj_XX: array<int32>,
#         AF_asj_XX: array<float64>,
#         AN_asj_XX: int32,
#         nhomalt_asj_XX: array<int32>,
#         AC_asj_XY: array<int32>,
#         AF_asj_XY: array<float64>,
#         AN_asj_XY: int32,
#         nhomalt_asj_XY: array<int32>,
#         AC_asj: array<int32>,
#         AF_asj: array<float64>,
#         AN_asj: int32,
#         nhomalt_asj: array<int32>,
#         AC_eas_XX: array<int32>,
#         AF_eas_XX: array<float64>,
#         AN_eas_XX: int32,
#         nhomalt_eas_XX: array<int32>,
#         AC_eas_XY: array<int32>,
#         AF_eas_XY: array<float64>,
#         AN_eas_XY: int32,
#         nhomalt_eas_XY: array<int32>,
#         AC_eas: array<int32>,
#         AF_eas: array<float64>,
#         AN_eas: int32,
#         nhomalt_eas: array<int32>,
#         AC_fin_XX: array<int32>,
#         AF_fin_XX: array<float64>,
#         AN_fin_XX: int32,
#         nhomalt_fin_XX: array<int32>,
#         AC_fin_XY: array<int32>,
#         AF_fin_XY: array<float64>,
#         AN_fin_XY: int32,
#         nhomalt_fin_XY: array<int32>,
#         AC_fin: array<int32>,
#         AF_fin: array<float64>,
#         AN_fin: int32,
#         nhomalt_fin: array<int32>,
#         AC_mid_XX: array<int32>,
#         AF_mid_XX: array<float64>,
#         AN_mid_XX: int32,
#         nhomalt_mid_XX: array<int32>,
#         AC_mid_XY: array<int32>,
#         AF_mid_XY: array<float64>,
#         AN_mid_XY: int32,
#         nhomalt_mid_XY: array<int32>,
#         AC_mid: array<int32>,
#         AF_mid: array<float64>,
#         AN_mid: int32,
#         nhomalt_mid: array<int32>,
#         AC_nfe_XX: array<int32>,
#         AF_nfe_XX: array<float64>,
#         AN_nfe_XX: int32,
#         nhomalt_nfe_XX: array<int32>,
#         AC_nfe_XY: array<int32>,
#         AF_nfe_XY: array<float64>,
#         AN_nfe_XY: int32,
#         nhomalt_nfe_XY: array<int32>,
#         AC_nfe: array<int32>,
#         AF_nfe: array<float64>,
#         AN_nfe: int32,
#         nhomalt_nfe: array<int32>,
#         AC_non_ukb_XX: array<int32>,
#         AF_non_ukb_XX: array<float64>,
#         AN_non_ukb_XX: int32,
#         nhomalt_non_ukb_XX: array<int32>,
#         AC_non_ukb_XY: array<int32>,
#         AF_non_ukb_XY: array<float64>,
#         AN_non_ukb_XY: int32,
#         nhomalt_non_ukb_XY: array<int32>,
#         AC_non_ukb: array<int32>,
#         AF_non_ukb: array<float64>,
#         AN_non_ukb: int32,
#         nhomalt_non_ukb: array<int32>,
#         AC_non_ukb_afr_XX: array<int32>,
#         AF_non_ukb_afr_XX: array<float64>,
#         AN_non_ukb_afr_XX: int32,
#         nhomalt_non_ukb_afr_XX: array<int32>,
#         AC_non_ukb_afr_XY: array<int32>,
#         AF_non_ukb_afr_XY: array<float64>,
#         AN_non_ukb_afr_XY: int32,
#         nhomalt_non_ukb_afr_XY: array<int32>,
#         AC_non_ukb_afr: array<int32>,
#         AF_non_ukb_afr: array<float64>,
#         AN_non_ukb_afr: int32,
#         nhomalt_non_ukb_afr: array<int32>,
#         AC_non_ukb_amr_XX: array<int32>,
#         AF_non_ukb_amr_XX: array<float64>,
#         AN_non_ukb_amr_XX: int32,
#         nhomalt_non_ukb_amr_XX: array<int32>,
#         AC_non_ukb_amr_XY: array<int32>,
#         AF_non_ukb_amr_XY: array<float64>,
#         AN_non_ukb_amr_XY: int32,
#         nhomalt_non_ukb_amr_XY: array<int32>,
#         AC_non_ukb_amr: array<int32>,
#         AF_non_ukb_amr: array<float64>,
#         AN_non_ukb_amr: int32,
#         nhomalt_non_ukb_amr: array<int32>,
#         AC_non_ukb_asj_XX: array<int32>,
#         AF_non_ukb_asj_XX: array<float64>,
#         AN_non_ukb_asj_XX: int32,
#         nhomalt_non_ukb_asj_XX: array<int32>,
#         AC_non_ukb_asj_XY: array<int32>,
#         AF_non_ukb_asj_XY: array<float64>,
#         AN_non_ukb_asj_XY: int32,
#         nhomalt_non_ukb_asj_XY: array<int32>,
#         AC_non_ukb_asj: array<int32>,
#         AF_non_ukb_asj: array<float64>,
#         AN_non_ukb_asj: int32,
#         nhomalt_non_ukb_asj: array<int32>,
#         AC_non_ukb_eas_XX: array<int32>,
#         AF_non_ukb_eas_XX: array<float64>,
#         AN_non_ukb_eas_XX: int32,
#         nhomalt_non_ukb_eas_XX: array<int32>,
#         AC_non_ukb_eas_XY: array<int32>,
#         AF_non_ukb_eas_XY: array<float64>,
#         AN_non_ukb_eas_XY: int32,
#         nhomalt_non_ukb_eas_XY: array<int32>,
#         AC_non_ukb_eas: array<int32>,
#         AF_non_ukb_eas: array<float64>,
#         AN_non_ukb_eas: int32,
#         nhomalt_non_ukb_eas: array<int32>,
#         AC_non_ukb_fin_XX: array<int32>,
#         AF_non_ukb_fin_XX: array<float64>,
#         AN_non_ukb_fin_XX: int32,
#         nhomalt_non_ukb_fin_XX: array<int32>,
#         AC_non_ukb_fin_XY: array<int32>,
#         AF_non_ukb_fin_XY: array<float64>,
#         AN_non_ukb_fin_XY: int32,
#         nhomalt_non_ukb_fin_XY: array<int32>,
#         AC_non_ukb_fin: array<int32>,
#         AF_non_ukb_fin: array<float64>,
#         AN_non_ukb_fin: int32,
#         nhomalt_non_ukb_fin: array<int32>,
#         AC_non_ukb_mid_XX: array<int32>,
#         AF_non_ukb_mid_XX: array<float64>,
#         AN_non_ukb_mid_XX: int32,
#         nhomalt_non_ukb_mid_XX: array<int32>,
#         AC_non_ukb_mid_XY: array<int32>,
#         AF_non_ukb_mid_XY: array<float64>,
#         AN_non_ukb_mid_XY: int32,
#         nhomalt_non_ukb_mid_XY: array<int32>,
#         AC_non_ukb_mid: array<int32>,
#         AF_non_ukb_mid: array<float64>,
#         AN_non_ukb_mid: int32,
#         nhomalt_non_ukb_mid: array<int32>,
#         AC_non_ukb_nfe_XX: array<int32>,
#         AF_non_ukb_nfe_XX: array<float64>,
#         AN_non_ukb_nfe_XX: int32,
#         nhomalt_non_ukb_nfe_XX: array<int32>,
#         AC_non_ukb_nfe_XY: array<int32>,
#         AF_non_ukb_nfe_XY: array<float64>,
#         AN_non_ukb_nfe_XY: int32,
#         nhomalt_non_ukb_nfe_XY: array<int32>,
#         AC_non_ukb_nfe: array<int32>,
#         AF_non_ukb_nfe: array<float64>,
#         AN_non_ukb_nfe: int32,
#         nhomalt_non_ukb_nfe: array<int32>,
#         AC_non_ukb_raw: array<int32>,
#         AF_non_ukb_raw: array<float64>,
#         AN_non_ukb_raw: int32,
#         nhomalt_non_ukb_raw: array<int32>,
#         AC_non_ukb_remaining_XX: array<int32>,
#         AF_non_ukb_remaining_XX: array<float64>,
#         AN_non_ukb_remaining_XX: int32,
#         nhomalt_non_ukb_remaining_XX: array<int32>,
#         AC_non_ukb_remaining_XY: array<int32>,
#         AF_non_ukb_remaining_XY: array<float64>,
#         AN_non_ukb_remaining_XY: int32,
#         nhomalt_non_ukb_remaining_XY: array<int32>,
#         AC_non_ukb_remaining: array<int32>,
#         AF_non_ukb_remaining: array<float64>,
#         AN_non_ukb_remaining: int32,
#         nhomalt_non_ukb_remaining: array<int32>,
#         AC_non_ukb_sas_XX: array<int32>,
#         AF_non_ukb_sas_XX: array<float64>,
#         AN_non_ukb_sas_XX: int32,
#         nhomalt_non_ukb_sas_XX: array<int32>,
#         AC_non_ukb_sas_XY: array<int32>,
#         AF_non_ukb_sas_XY: array<float64>,
#         AN_non_ukb_sas_XY: int32,
#         nhomalt_non_ukb_sas_XY: array<int32>,
#         AC_non_ukb_sas: array<int32>,
#         AF_non_ukb_sas: array<float64>,
#         AN_non_ukb_sas: int32,
#         nhomalt_non_ukb_sas: array<int32>,
#         AC_raw: array<int32>,
#         AF_raw: array<float64>,
#         AN_raw: int32,
#         nhomalt_raw: array<int32>,
#         AC_remaining_XX: array<int32>,
#         AF_remaining_XX: array<float64>,
#         AN_remaining_XX: int32,
#         nhomalt_remaining_XX: array<int32>,
#         AC_remaining_XY: array<int32>,
#         AF_remaining_XY: array<float64>,
#         AN_remaining_XY: int32,
#         nhomalt_remaining_XY: array<int32>,
#         AC_remaining: array<int32>,
#         AF_remaining: array<float64>,
#         AN_remaining: int32,
#         nhomalt_remaining: array<int32>,
#         AC_sas_XX: array<int32>,
#         AF_sas_XX: array<float64>,
#         AN_sas_XX: int32,
#         nhomalt_sas_XX: array<int32>,
#         AC_sas_XY: array<int32>,
#         AF_sas_XY: array<float64>,
#         AN_sas_XY: int32,
#         nhomalt_sas_XY: array<int32>,
#         AC_sas: array<int32>,
#         AF_sas: array<float64>,
#         AN_sas: int32,
#         nhomalt_sas: array<int32>,
#         AC_grpmax: array<int32>,
#         AF_grpmax: array<float64>,
#         AN_grpmax: array<int32>,
#         nhomalt_grpmax: array<int32>,
#         grpmax_non_ukb: array<str>,
#         AC_grpmax_non_ukb: array<int32>,
#         AF_grpmax_non_ukb: array<float64>,
#         AN_grpmax_non_ukb: array<int32>,
#         nhomalt_grpmax_non_ukb: array<int32>,
#         faf95_XX: array<float64>,
#         faf95_XY: array<float64>,
#         faf95: array<float64>,
#         faf95_afr_XX: array<float64>,
#         faf95_afr_XY: array<float64>,
#         faf95_afr: array<float64>,
#         faf95_amr_XX: array<float64>,
#         faf95_amr_XY: array<float64>,
#         faf95_amr: array<float64>,
#         faf95_eas_XX: array<float64>,
#         faf95_eas_XY: array<float64>,
#         faf95_eas: array<float64>,
#         faf95_mid_XX: array<float64>,
#         faf95_mid_XY: array<float64>,
#         faf95_mid: array<float64>,
#         faf95_nfe_XX: array<float64>,
#         faf95_nfe_XY: array<float64>,
#         faf95_nfe: array<float64>,
#         faf95_non_ukb_XX: array<float64>,
#         faf95_non_ukb_XY: array<float64>,
#         faf95_non_ukb: array<float64>,
#         faf95_non_ukb_afr_XX: array<float64>,
#         faf95_non_ukb_afr_XY: array<float64>,
#         faf95_non_ukb_afr: array<float64>,
#         faf95_non_ukb_amr_XX: array<float64>,
#         faf95_non_ukb_amr_XY: array<float64>,
#         faf95_non_ukb_amr: array<float64>,
#         faf95_non_ukb_eas_XX: array<float64>,
#         faf95_non_ukb_eas_XY: array<float64>,
#         faf95_non_ukb_eas: array<float64>,
#         faf95_non_ukb_mid_XX: array<float64>,
#         faf95_non_ukb_mid_XY: array<float64>,
#         faf95_non_ukb_mid: array<float64>,
#         faf95_non_ukb_nfe_XX: array<float64>,
#         faf95_non_ukb_nfe_XY: array<float64>,
#         faf95_non_ukb_nfe: array<float64>,
#         faf95_non_ukb_sas_XX: array<float64>,
#         faf95_non_ukb_sas_XY: array<float64>,
#         faf95_non_ukb_sas: array<float64>,
#         faf95_sas_XX: array<float64>,
#         faf95_sas_XY: array<float64>,
#         faf95_sas: array<float64>,
#         faf99_XX: array<float64>,
#         faf99_XY: array<float64>,
#         faf99: array<float64>,
#         faf99_afr_XX: array<float64>,
#         faf99_afr_XY: array<float64>,
#         faf99_afr: array<float64>,
#         faf99_amr_XX: array<float64>,
#         faf99_amr_XY: array<float64>,
#         faf99_amr: array<float64>,
#         faf99_eas_XX: array<float64>,
#         faf99_eas_XY: array<float64>,
#         faf99_eas: array<float64>,
#         faf99_mid_XX: array<float64>,
#         faf99_mid_XY: array<float64>,
#         faf99_mid: array<float64>,
#         faf99_nfe_XX: array<float64>,
#         faf99_nfe_XY: array<float64>,
#         faf99_nfe: array<float64>,
#         faf99_non_ukb_XX: array<float64>,
#         faf99_non_ukb_XY: array<float64>,
#         faf99_non_ukb: array<float64>,
#         faf99_non_ukb_afr_XX: array<float64>,
#         faf99_non_ukb_afr_XY: array<float64>,
#         faf99_non_ukb_afr: array<float64>,
#         faf99_non_ukb_amr_XX: array<float64>,
#         faf99_non_ukb_amr_XY: array<float64>,
#         faf99_non_ukb_amr: array<float64>,
#         faf99_non_ukb_eas_XX: array<float64>,
#         faf99_non_ukb_eas_XY: array<float64>,
#         faf99_non_ukb_eas: array<float64>,
#         faf99_non_ukb_mid_XX: array<float64>,
#         faf99_non_ukb_mid_XY: array<float64>,
#         faf99_non_ukb_mid: array<float64>,
#         faf99_non_ukb_nfe_XX: array<float64>,
#         faf99_non_ukb_nfe_XY: array<float64>,
#         faf99_non_ukb_nfe: array<float64>,
#         faf99_non_ukb_sas_XX: array<float64>,
#         faf99_non_ukb_sas_XY: array<float64>,
#         faf99_non_ukb_sas: array<float64>,
#         faf99_sas_XX: array<float64>,
#         faf99_sas_XY: array<float64>,
#         faf99_sas: array<float64>,
#         fafmax_faf99_max: array<float64>,
#         fafmax_faf99_max_gen_anc: array<str>,
#         fafmax_faf95_max_non_ukb: array<float64>,
#         fafmax_faf95_max_gen_anc_non_ukb: array<str>,
#         fafmax_faf99_max_non_ukb: array<float64>,
#         fafmax_faf99_max_gen_anc_non_ukb: array<str>,
#         age_hist_het_bin_freq: array<str>,
#         age_hist_het_n_smaller: array<int32>,
#         age_hist_het_n_larger: array<int32>,
#         age_hist_hom_bin_freq: array<str>,
#         age_hist_hom_n_smaller: array<int32>,
#         age_hist_hom_n_larger: array<int32>,
#         FS: float64,
#         MQ: float64,
#         MQRankSum: float64,
#         QUALapprox: int32,
#         QD: float64,
#         ReadPosRankSum: float64,
#         SOR: float64,
#         VarDP: int32,
#         monoallelic: bool,
#         only_het: bool,
#         transmitted_singleton: bool,
#         sibling_singleton: bool,
#         AS_FS: array<float64>,
#         AS_MQ: array<float64>,
#         AS_MQRankSum: array<float64>,
#         AS_pab_max: array<float64>,
#         AS_QUALapprox: array<int32>,
#         AS_QD: array<float64>,
#         AS_ReadPosRankSum: array<float64>,
#         AS_SB_TABLE: array<str>,
#         AS_SOR: array<float64>,
#         AS_VarDP: array<int32>,
#         inbreeding_coeff: array<float64>,
#         AS_culprit: array<str>,
#         AS_VQSLOD: array<float64>,
#         negative_train_site: bool,
#         positive_train_site: bool,
#         allele_type: str,
#         n_alt_alleles: int32,
#         variant_type: str,
#         was_mixed: bool,
#         lcr: bool,
#         non_par: bool,
#         segdup: bool,
#         fail_interval_qc: bool,
#         outside_ukb_capture_region: bool,
#         outside_broad_capture_region: bool,
#         gq_hist_alt_bin_freq: array<str>,
#         gq_hist_all_bin_freq: array<str>,
#         dp_hist_alt_bin_freq: array<str>,
#         dp_hist_alt_n_larger: array<int32>,
#         dp_hist_all_bin_freq: array<str>,
#         dp_hist_all_n_larger: array<int32>,
#         ab_hist_alt_bin_freq: array<str>,
#         cadd_raw_score: float64,
#         cadd_phred: float64,
#         revel_max: float64,
#         spliceai_ds_max: float64,
#         pangolin_largest_ds: float64,
#         phylop: float64,
#         sift_max: float64,
#         polyphen_max: float64,
#         VRS_Allele_IDs: array<str>,
#         VRS_Starts: array<int32>,
#         VRS_Ends: array<int32>,
#         VRS_States: array<str>,
#         vep: array<str>
#     }
# ----------------------------------------
# Entry fields:
#     None
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %%
# Extract gnomAD statistics from info field
variants = mt.rows()

# %%
# helper function to extract info field
def first_or_default(expr, default):
    return hl.if_else(hl.len(expr) > 0, expr[0], default)

# %%
# Select relevant fields from the info struct
variants = variants.select(
    # Locus information
    chrom=variants.locus.contig,
    pos=variants.locus.position,
    ref=variants.alleles[0],
    alt=hl.delimit(variants.alleles[1:], ','),  # Join alt alleles if multiple
    rsid=variants.rsid,

    # Basic allele statistics (from gnomAD info field)
    AC=first_or_default(variants.info.AC, 0),
    AN=variants.info.AN,
    AF=first_or_default(variants.info.AF, 0.0),

    # Genetic ancestry group with max AF
    grpmax=first_or_default(variants.info.grpmax, ''),

    # Filtering Allele Frequency (95% confidence)
    faf95_max=first_or_default(variants.info.fafmax_faf95_max, 0.0),
    faf95_max_gen_anc=first_or_default(variants.info.fafmax_faf95_max_gen_anc, ''),

    # Number of homozygotes
    nhomalt=first_or_default(variants.info.nhomalt, 0),

    # Sex-specific counts
    AC_XX=first_or_default(variants.info.AC_XX, 0),
    AN_XX=variants.info.AN_XX,
    AF_XX=first_or_default(variants.info.AF_XX, 0.0),
    nhomalt_XX=first_or_default(variants.info.nhomalt_XX, 0),

    AC_XY=first_or_default(variants.info.AC_XY, 0),
    AN_XY=variants.info.AN_XY,
    AF_XY=first_or_default(variants.info.AF_XY, 0.0),
    nhomalt_XY=first_or_default(variants.info.nhomalt_XY, 0),

    # Population-specific (examples)
    AC_afr=first_or_default(variants.info.AC_afr, 0),
    AF_afr=first_or_default(variants.info.AF_afr, 0.0),
    AN_afr=variants.info.AN_afr,

    AC_amr=first_or_default(variants.info.AC_amr, 0),
    AF_amr=first_or_default(variants.info.AF_amr, 0.0),
    AN_amr=variants.info.AN_amr,

    AC_eas=first_or_default(variants.info.AC_eas, 0),
    AF_eas=first_or_default(variants.info.AF_eas, 0.0),
    AN_eas=variants.info.AN_eas,

    AC_nfe=first_or_default(variants.info.AC_nfe, 0),
    AF_nfe=first_or_default(variants.info.AF_nfe, 0.0),
    AN_nfe=variants.info.AN_nfe,

    AC_sas=first_or_default(variants.info.AC_sas, 0),
    AF_sas=first_or_default(variants.info.AF_sas, 0.0),
    AN_sas=variants.info.AN_sas,

    # Prediction scores
    cadd_phred=variants.info.cadd_phred,
    revel_max=variants.info.revel_max,
    spliceai_ds_max=variants.info.spliceai_ds_max,

    # Quality metrics
    qual=variants.qual,
    filters=hl.delimit(variants.filters, ','),
)

# %%
# Convert to pandas
df = variants.to_pandas()

print("\n=== Variant Statistics ===")
print(f"Total variants: {len(df):,}")
print("\nFirst few variants:")
print(df.head(10))

# Export to TSV for Streamlit
output_tsv = '../data/variant_stats.tsv'
variants.export(output_tsv)
print(f"\nExported to: {output_tsv}")

# Summary statistics
print("\n=== Summary Statistics ===")
print(f"Mean Allele Count: {df['AC'].mean():.2f}")
print(f"Mean Allele Frequency: {df['AF'].mean():.6f}")
print(f"Mean Allele Number: {df['AN'].mean():.2f}")
print(f"Total Homozygotes: {df['nhomalt'].sum():,}")
print(f"\nChromosomes present: {sorted(df['chrom'].unique())}")
print(f"Variants with rsID: {df['rsid'].notna().sum():,}")
# Out:
# === Variant Statistics ===
# Total variants: 2,000
#
# First few variants:
#           locus       alleles  chrom     pos      ref  alt          rsid  \
# 0   chr18:48494        [T, A]  chr18   48494        T    A  rs1905848822
# 1   chr18:87087       [TG, T]  chr18   87087       TG    T          <NA>
# 2  chr18:109438        [T, C]  chr18  109438        T    C  rs1462125550
# 3  chr18:109567      [C, CCT]  chr18  109567        C  CCT          <NA>
# 4  chr18:112506  [CCTCCAG, C]  chr18  112506  CCTCCAG    C          <NA>
# 5  chr18:223630        [C, A]  chr18  223630        C    A          <NA>
# 6  chr18:224952        [C, A]  chr18  224952        C    A          <NA>
# 7  chr18:225235        [C, T]  chr18  225235        C    T  rs1911240230
# 8  chr18:225321        [T, C]  chr18  225321        T    C   rs755941042
# 9  chr18:260110        [A, G]  chr18  260110        A    G   rs540995383
#
#      AC    AN        AF  ...    AF_nfe   AN_nfe AC_sas  AF_sas  AN_sas  \
# 0  <NA>  <NA>  0.000001  ...       0.0   627824      0     0.0   71926
# 1  <NA>  <NA>  0.000002  ...  0.000003   734590      0     0.0   71254
# 2  <NA>  <NA>       0.0  ...       0.0     1792      0     0.0      72
# 3  <NA>  <NA>       0.0  ...       0.0      758      0     0.0      10
# 4  <NA>  <NA>       0.0  ...       0.0   329612      0     0.0   65876
# 5  <NA>  <NA>       0.0  ...       0.0   370296      0     0.0   38710
# 6  <NA>  <NA>       0.0  ...       0.0  1090060      0     0.0   81342
# 7  <NA>  <NA>  0.000003  ...  0.000004  1057478      0     0.0   80016
# 8  <NA>  <NA>  0.000001  ...       0.0  1111064      0     0.0   86156
# 9  <NA>  <NA>  0.000007  ...       0.0   529738      0     0.0   28292
#
#    cadd_phred  revel_max  spliceai_ds_max  qual      filters
# 0        5.98       <NA>             <NA>  <NA>      AS_VQSR
# 1       0.448       <NA>             <NA>  <NA>      AS_VQSR
# 2        10.8       <NA>             <NA>  <NA>  AC0,AS_VQSR
# 3       6.385       <NA>             <NA>  <NA>  AC0,AS_VQSR
# 4       5.847       <NA>             <NA>  <NA>  AC0,AS_VQSR
# 5       8.928       <NA>              0.0  <NA>          AC0
# 6        43.0       <NA>             0.05  <NA>          AC0
# 7        20.8       <NA>             0.09  <NA>
# 8        20.4       <NA>              0.0  <NA>
# 9        0.77       <NA>              0.0  <NA>
#
# [10 rows x 42 columns]
#
# Exported to: ../data/variant_stats.tsv
#
# === Summary Statistics ===
# Mean Allele Count: <NA>
# Mean Allele Frequency: 0.001223
# Mean Allele Number: <NA>
# Total Homozygotes: 784
#
# Chromosomes present: ['chr18', 'chr21']
# Variants with rsID: 593
